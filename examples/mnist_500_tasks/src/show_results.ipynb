# %%
import numpy as np
import matplotlib.pyplot as plt

print("Start Draw")
results = np.genfromtxt('./result/results.csv', delimiter=",", names=["LR","ACC"])
# pd.read_csv(file)
plt.plot(results["LR"], results["ACC"])
plt.show()
plt.savefig('eva.png')
